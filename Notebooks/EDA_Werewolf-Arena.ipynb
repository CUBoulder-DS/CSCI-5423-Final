# %% [raw]
# ---
# author: Bhavana Jonnalagadda
# ---

# %% [markdown]
# # Werewolf Arena - LLM WAU Dataset EDA
#
# Exploratory data analysis, data loading and transforming

# %%
import ast
import os
import json
import random 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter
from itertools import chain

random.seed(42)

# %%
basepath = os.path.normpath("../Data/Werewolf-Arena")
out_path = os.path.normpath("../Data/Output/EDA_WA/")

# %% [markdown]
# ## Load and transform data

# %%
# Process all games into a general rounds DF, and a DF by each utterance

rounds = []
utterances = []
for folder in os.listdir(basepath):
    if not folder.startswith("session_"):
        continue
    
    game_df = pd.read_json(os.path.join(basepath, folder, "game_complete.json"), orient="index").T
    playerinfo = game_df["players"].to_dict()[0]
    players = {k: v["role"] for k, v in playerinfo.items()}
    
    rounds_df = pd.DataFrame(game_df["rounds"][0])
    rounds_df["session_id"]  = int(random.random() * 1000)
    # rounds_df["session_id"]  = game_df["session_id"][0] # Session ID is always 10 in the files....
    rounds_df["winner"]  = game_df["winner"][0]
    rounds_df["round"] = rounds_df.index
    rounds_df["roles"] = rounds_df["players"].map(lambda x: [players[i] for i in x])
    rounds_df["models"] = rounds_df["players"].map(lambda x: [playerinfo[i]["model"] for i in x])
    rounds_df = rounds_df.drop(columns="bids")
    
    utterances_df = rounds_df.explode(["debate", "votes"], ignore_index=True)
    utterances_df["debate"] = utterances_df["debate"].fillna("00").apply(list) # Deal with NaN text
    utterances_df[["speaker", "text"]] = utterances_df["debate"].tolist()
    utterances_df["votes"] = utterances_df["votes"].to_dict()
    utterances_df["timestamp"] = utterances_df.index
    utterances_df = utterances_df.drop(columns=["debate"])
    
    rounds_df = rounds_df.drop(columns=["debate", "votes"])
    rounds.append(rounds_df)
    utterances.append(utterances_df)

allrounds_df = pd.concat(rounds, ignore_index=True)
alltext_df = pd.concat(utterances, ignore_index=True)

# %% [markdown]
# BID OPTIONS:
#
# - 0: I would like to observe and listen for now.
# - 1: I have some general thoughts to share with the group.
# - 2: I have something critical and specific to contribute to this discussion.
# - 3: It is absolutely urgent for me to speak next.
# - 4: Someone has addressed me directly and I must respond

# %% [markdown]
# ### Save transformed data into CSVs

# %%
allrounds_df = allrounds_df.rename(columns={"session_id": "game_id"})
print(allrounds_df.info())

allrounds_df.to_csv(os.path.join(out_path, "allrounds.csv"))
allrounds_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   players     63 non-null     object
#  1   eliminated  63 non-null     object
#  2   unmasked    40 non-null     object
#  3   protected   49 non-null     object
#  4   exiled      37 non-null     object
#  5   success     63 non-null     bool
#  6   game_id     63 non-null     int64
#  7   winner      63 non-null     object
#  8   round       63 non-null     int64
#  9   roles       63 non-null     object
#  10  models      63 non-null     object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 5.1+ KB
# None
#                                               players eliminated unmasked  \
# 0   [Harold, Will, Sam, Jackson, Hayley, Jacob, Ma...        Dan     Will
# 1        [Harold, Sam, Jackson, Hayley, Jacob, Mason]       Will     None
# 2                         [Sam, Hayley, Jacob, Mason]     Harold     None
# 3         [Jackson, Mason, Ginger, Scott, Sam, Jacob]       Paul     Paul
# 4                        [Jackson, Scott, Sam, Jacob]      Mason   Ginger
# ..                                                ...        ...      ...
# 58          [Mason, Jacob, Dan, Bert, Ginger, Harold]     Hayley    Mason
# 59                       [Jacob, Dan, Ginger, Harold]      Mason     Bert
# 60  [Mason, Dan, Paul, Jackson, Sam, Hayley, Derek...      Mason     Paul
# 61          [Mason, Dan, Paul, Hayley, Derek, Harold]    Jackson  Jackson
# 62                  [Mason, Dan, Paul, Derek, Harold]     Harold   Hayley
#
#    protected   exiled  success  game_id      winner  round  \
# 0     Hayley     None     True      861  Werewolves      0
# 1        Sam     None     True      861  Werewolves      1
# 2        Sam  Jackson     True      861  Werewolves      2
# 3    Jackson      Dan     True      577   Villagers      0
# 4        Sam   Ginger     True      577   Villagers      1
# ..       ...      ...      ...      ...         ...    ...
# 58    Ginger    David     True      609   Villagers      0
# 59    Harold     Bert     True      609   Villagers      1
# 60     Mason     None     True      171   Villagers      0
# 61    Harold      Sam     True      171   Villagers      1
# 62    Harold   Hayley     True      171   Villagers      2
#
#                                                 roles  \
# 0   [Villager, Villager, Villager, Villager, Werew...
# 1   [Villager, Villager, Villager, Werewolf, Werew...
# 2              [Villager, Werewolf, Werewolf, Doctor]
# 3   [Villager, Villager, Werewolf, Werewolf, Docto...
# 4                  [Villager, Werewolf, Doctor, Seer]
# ..                                                ...
# 58  [Villager, Villager, Villager, Werewolf, Docto...
# 59                 [Villager, Villager, Doctor, Seer]
# 60  [Villager, Villager, Villager, Villager, Werew...
# 61  [Villager, Villager, Villager, Werewolf, Docto...
# 62       [Villager, Villager, Villager, Doctor, Seer]
#
#                                                models
# 0   [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...
# 1   [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...
# 2   [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...
# 3   [gpt-4.1-2025-04-14, gpt-4.1-2025-04-14, deeps...
# 4   [gpt-4.1-2025-04-14, deepseek-chat, gpt-4.1-20...
# ..                                                ...
# 58  [deepseek-reasoner, deepseek-reasoner, deepsee...
# 59  [deepseek-reasoner, deepseek-reasoner, deepsee...
# 60  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...
# 61  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...
# 62  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...
#
# [63 rows x 11 columns]

# %%
strategies_df = pd.read_csv(os.path.join(out_path, "annotations.csv"), index_col=0)
strategies_df
# Out:
#                                               strategy
# 0    ['Interrogation', 'Accusation', 'Call for Acti...
# 1    ['Interrogation', 'Accusation', 'Call for Acti...
# 2     ['Interrogation', 'Evidence', 'Call for Action']
# 3    ['Defense', 'Call for Action', 'Identity Decla...
# 4    ['Interrogation', 'Accusation', 'Defense', 'Ev...
# ..                                                 ...
# 436  ['Accusation', 'Evidence', 'Call for Action', ...
# 437  ['Accusation', 'Evidence', 'Call for Action', ...
# 438  ['Evidence', 'Call for Action', 'Identity Decl...
# 439  ['Accusation', 'Evidence', 'Call for Action', ...
# 440  ['Interrogation', 'Accusation', 'Defense', 'Ev...
#
# [441 rows x 1 columns]

# %%
alltext_df = alltext_df.rename(columns={"session_id": "game_id"})
alltext_df["strategy"] = strategies_df["strategy"]
print(alltext_df.info())

alltext_df.to_csv(os.path.join(out_path, "alltext.csv"))
alltext_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   players     441 non-null    object
#  1   eliminated  441 non-null    object
#  2   unmasked    306 non-null    object
#  3   protected   363 non-null    object
#  4   exiled      280 non-null    object
#  5   votes       436 non-null    object
#  6   success     441 non-null    bool
#  7   game_id     441 non-null    int64
#  8   winner      441 non-null    object
#  9   round       441 non-null    int64
#  10  roles       441 non-null    object
#  11  models      441 non-null    object
#  12  speaker     441 non-null    object
#  13  text        441 non-null    object
#  14  timestamp   441 non-null    int64
#  15  strategy    441 non-null    object
# dtypes: bool(1), int64(3), object(12)
# memory usage: 52.2+ KB
# None
#                                                players eliminated unmasked  \
# 0    [Harold, Will, Sam, Jackson, Hayley, Jacob, Ma...        Dan     Will
# 1    [Harold, Will, Sam, Jackson, Hayley, Jacob, Ma...        Dan     Will
# 2    [Harold, Will, Sam, Jackson, Hayley, Jacob, Ma...        Dan     Will
# 3    [Harold, Will, Sam, Jackson, Hayley, Jacob, Ma...        Dan     Will
# 4    [Harold, Will, Sam, Jackson, Hayley, Jacob, Ma...        Dan     Will
# ..                                                 ...        ...      ...
# 436                  [Mason, Dan, Paul, Derek, Harold]     Harold   Hayley
# 437                  [Mason, Dan, Paul, Derek, Harold]     Harold   Hayley
# 438                  [Mason, Dan, Paul, Derek, Harold]     Harold   Hayley
# 439                  [Mason, Dan, Paul, Derek, Harold]     Harold   Hayley
# 440                  [Mason, Dan, Paul, Derek, Harold]     Harold   Hayley
#
#     protected  exiled                                              votes  \
# 0      Hayley    None  {'Harold': 'Jackson', 'Will': 'Jackson', 'Sam'...
# 1      Hayley    None  {'Harold': 'Jackson', 'Will': 'Mason', 'Sam': ...
# 2      Hayley    None  {'Harold': 'Jackson', 'Will': 'Jackson', 'Sam'...
# 3      Hayley    None  {'Harold': 'Jacob', 'Will': 'Jacob', 'Sam': 'J...
# 4      Hayley    None  {'Harold': 'Jacob', 'Will': 'Jacob', 'Sam': 'J...
# ..        ...     ...                                                ...
# 436    Harold  Hayley  {'Mason': 'Paul', 'Dan': 'Hayley', 'Paul': 'Ha...
# 437    Harold  Hayley  {'Mason': 'Hayley', 'Dan': 'Hayley', 'Paul': '...
# 438    Harold  Hayley  {'Mason': 'Hayley', 'Dan': 'Hayley', 'Paul': '...
# 439    Harold  Hayley  {'Mason': 'Hayley', 'Dan': 'Hayley', 'Paul': '...
# 440    Harold  Hayley  {'Mason': 'Hayley', 'Dan': 'Hayley', 'Paul': '...
#
#      success  game_id      winner  round  \
# 0       True      861  Werewolves      0
# 1       True      861  Werewolves      0
# 2       True      861  Werewolves      0
# 3       True      861  Werewolves      0
# 4       True      861  Werewolves      0
# ..       ...      ...         ...    ...
# 436     True      171   Villagers      2
# 437     True      171   Villagers      2
# 438     True      171   Villagers      2
# 439     True      171   Villagers      2
# 440     True      171   Villagers      2
#
#                                                  roles  \
# 0    [Villager, Villager, Villager, Villager, Werew...
# 1    [Villager, Villager, Villager, Villager, Werew...
# 2    [Villager, Villager, Villager, Villager, Werew...
# 3    [Villager, Villager, Villager, Villager, Werew...
# 4    [Villager, Villager, Villager, Villager, Werew...
# ..                                                 ...
# 436       [Villager, Villager, Villager, Doctor, Seer]
# 437       [Villager, Villager, Villager, Doctor, Seer]
# 438       [Villager, Villager, Villager, Doctor, Seer]
# 439       [Villager, Villager, Villager, Doctor, Seer]
# 440       [Villager, Villager, Villager, Doctor, Seer]
#
#                                                 models  speaker  \
# 0    [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...     Will
# 1    [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...   Hayley
# 2    [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...    Jacob
# 3    [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...  Jackson
# 4    [gpt-4o-2024-05-13, gpt-4o-2024-05-13, gpt-4o-...    Jacob
# ..                                                 ...      ...
# 436  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...   Harold
# 437  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...   Hayley
# 438  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...   Harold
# 439  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...     Paul
# 440  [gpt-4o-mini-2024-07-18, gpt-4o-mini-2024-07-1...   Hayley
#
#                                                   text  timestamp  \
# 0    Alright everyone, it's unfortunate that we've ...          0
# 1    Thanks, Will. It's indeed a tough start losing...          1
# 2    Thanks, Hayley. I agree with you and Will that...          2
# 3    Jacob, I appreciate you pointing out that I wa...          3
# 4    Thanks for addressing that, Jackson. I complet...          4
# ..                                                 ...        ...
# 436  Hayley, your accusations are unfounded and ser...         19
# 437  Harold, your insistence on labeling me as the ...         20
# 438  Hayley, your tactics of distraction are transp...         21
# 439  I want to echo what Harold has shared with us:...         22
# 440  I appreciate the spirited debate, but it's cru...         23
#
#                                               strategy
# 0    ['Interrogation', 'Accusation', 'Call for Acti...
# 1    ['Interrogation', 'Accusation', 'Call for Acti...
# 2     ['Interrogation', 'Evidence', 'Call for Action']
# 3    ['Defense', 'Call for Action', 'Identity Decla...
# 4    ['Interrogation', 'Accusation', 'Defense', 'Ev...
# ..                                                 ...
# 436  ['Accusation', 'Evidence', 'Call for Action', ...
# 437  ['Accusation', 'Evidence', 'Call for Action', ...
# 438  ['Evidence', 'Call for Action', 'Identity Decl...
# 439  ['Accusation', 'Evidence', 'Call for Action', ...
# 440  ['Interrogation', 'Accusation', 'Defense', 'Ev...
#
# [441 rows x 16 columns]

# %% [markdown]
# ## EDA
